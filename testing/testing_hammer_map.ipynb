# %%
import matplotlib.pyplot as plt
import geopandas
import pandas as pd
from cartopy import crs as ccrs

# %%
geopandas.GeoDataFrame

# %%
example_file = '/home/egor/PycharmProjects/deep_dr/logs/HyperSphericalVAE/run_5/latent.csv.gz'
latent_df = pd.read_csv(example_file)
print(latent_df.shape)
latent_df.head()
# Out:
# (234495, 3)
#        VAE1      VAE2      VAE3
# 0 -0.021631  0.973298  0.228460
# 1 -0.216141 -0.559700  0.799992
# 2  0.853338 -0.094025  0.512799
# 3  0.935533 -0.223390  0.273613
# 4 -0.846529 -0.462942 -0.262744

# %%
latent_df.head()
from datasets import OrganoidDataset, CellType

data = OrganoidDataset(device='cpu')
X_val, y_val = data.val
metadata = pd.DataFrame(y_val.cpu()).rename({0: "Cell type", 1: "Day"}, axis=1)
metadata['Cell type'] = metadata['Cell type'].replace({i.value: i.name for i in CellType}).astype(str)
metadata.head()
# Out:
#     Cell type  Day
# 0  Enterocyte  2.0
# 1  Enterocyte  7.0
# 2        Tuft  5.0
# 3        Tuft  2.0
# 4        Stem  7.0

# %%
import cartopy
from shapely.geometry import Point

sphere = geopandas.GeoSeries(latent_df.apply(Point, axis=1),crs=cartopy.crs.Geocentric())
sphere.head()
# Out:
# /home/egor/PycharmProjects/deep_dr/venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# 0      POINT Z (-0.02163 0.97330 0.22846)
# 1     POINT Z (-0.21614 -0.55970 0.79999)
# 2      POINT Z (0.85334 -0.09402 0.51280)
# 3      POINT Z (0.93553 -0.22339 0.27361)
# 4    POINT Z (-0.84653 -0.46294 -0.26274)
# dtype: geometry

# %%
# Out:
#                             Coordinates   Cell type  Day
# 0    POINT Z (-0.02163 0.97330 0.22846)  Enterocyte  2.0
# 1   POINT Z (-0.21614 -0.55970 0.79999)  Enterocyte  7.0
# 2    POINT Z (0.85334 -0.09402 0.51280)        Tuft  5.0
# 3    POINT Z (0.93553 -0.22339 0.27361)        Tuft  2.0
# 4  POINT Z (-0.84653 -0.46294 -0.26274)        Stem  7.0

# %%
projected = sphere.to_crs(cartopy.crs.Mollweide())

# %%
projected.x
# Out:
# 0         8.997532e+06
# 1        -8.091684e+06
# 2        -5.733496e+05
# 3        -1.314018e+06
# 4        -1.483513e+07
#               ...
# 234490   -4.029375e+06
# 234491    8.216898e+06
# 234492   -1.675166e+06
# 234493    1.198414e+07
# 234494    2.250548e+06
# Length: 234495, dtype: float64

# %%
data = pd.DataFrame({'x':projected.x,'y':projected.y,'Cell type':metadata['Cell type'],'Day':metadata['Day']})
data.head()
# Out:
#               x             y   Cell type  Day
# 0  8.997532e+06  1.627381e+06  Enterocyte  2.0
# 1 -8.091684e+06  6.197260e+06  Enterocyte  7.0
# 2 -5.733496e+05  3.743259e+06        Tuft  5.0
# 3 -1.314018e+06  1.953762e+06        Tuft  2.0
# 4 -1.483513e+07 -1.874991e+06        Stem  7.0

# %%
import seaborn as sns
sns.lmplot(x="x", y="y",
           data=data.head(10000),
           fit_reg=False,
           hue='Cell type',  # color by cluster
           legend=True,
           scatter_kws={"s": 5})
plt.axis('equal')
plt.savefig('sns_Mollweide.png')

# %%
import plotly.express as px
plot_data = pd.concat([latent_df, metadata], axis=1).head(5000)
fig = px.scatter_3d(plot_data, x='VAE1', y='VAE2', z='VAE3', color='Cell type')
fig.update_traces(marker_size = 3)
fig.write_html("plotly_3d.html")
fig.show()
# Out:
# <div>                            <div id="47cb1157-fcc6-457a-9525-b2db304d187f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47cb1157-fcc6-457a-9525-b2db304d187f")) {                    Plotly.newPlot(                        "47cb1157-fcc6-457a-9525-b2db304d187f",                        [{"hovertemplate":"Cell type=Enterocyte<br>VAE1=%{x}<br>VAE2=%{y}<br>VAE3=%{z}<extra></extra>","legendgroup":"Enterocyte","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"Enterocyte","scene":"scene","showlegend":true,"x":[-0.021630645,-0.21614069,-0.7492726,0.9959842,-0.81817263,-0.3160708,0.033783317,0.6573185,-0.7857291,-0.25793773,0.008297741,-0.31527555,0.7999779,-0.90365905,0.79816705,-0.022690177,0.8901536,-0.6661573,0.7144915,-0.020852566,-0.039918363,0.05024147,0.032502472,-0.91486394,-0.83297616,-0.050412,0.020970821,-0.33636403,0.6239482,0.95555925,-0.89798623,0.96077603,-0.5930868,-0.8707706,0.6008545,0.96927637,-0.9637372,0.9101093,0.89073515,-0.9146992,-0.5132802,-0.9541824,-0.8767179,-0.6307323,0.845331,-0.4316591,-0.91170526,-0.19970262,-0.9339523,0.99062294,-0.45311314,-0.5942347,-0.30014926,0.4347921,0.07928735,0.9689623,-0.8198176,0.16507685,0.66376495,0.83112526,0.9842483,-0.41857493,-0.5917871,-0.020042837,-0.9760741,-0.9360264,0.8929021,-0.6471507,0.9157868,0.8644036,-0.82922393,0.541368,0.77835953,0.9103403,0.9219331,-0.1741221,-0.632692,0.80264866,0.95464826,-0.14372855,-0.7071669,0.8435222,0.4349575,0.03226614,-0.3082323,-0.36659992,-0.7272631,-0.9647599,0.9525979,-0.13137525,0.71456313,0.23815942,-0.0035547018,-0.65028435,-0.18690419,0.40796196,0.14259326,-0.49075264,0.42727828,0.25612658,0.9198683,-0.79066694,0.61592364,-0.9353084,-0.6615751,0.037903666,-0.5149354,0.75547415,-0.41658717,0.93674016,0.040273547,-0.34932774,0.90470654,-0.53956085,0.9272359,0.66385174,-0.47941428,0.8531126,0.19023788,0.9979736,0.9037539,0.82868123,-0.21516752,-0.5151814,0.984636,-0.42230886,0.6422178,0.26054668,-0.012385309,0.9699614,0.35954738,0.08015323,0.97108376,-0.7241463,-0.3500638,-0.42338562,0.32418805,-0.20414531,-0.18271863,0.03952217,0.00012141466,0.8754533,-0.9647767,-0.10757941,-0.6329953,-0.38172293,-0.9153859,0.113236904,-0.012191057,-0.40699553,0.91696554,-0.86637616,0.9877926,0.18797463,-0.34610784,-0.15121776,0.55547667,-0.739938,-0.8224294,-0.42144275,0.93961847,-0.092253864,0.87094116,-0.935772,0.5994167,0.96956336,0.87020606,-0.38008827,-0.33439618,0.9523699,-0.92185235,0.15946841,-0.087635696,-0.625032,0.50506306,-0.78113014,-0.10688251,-0.89029926,-0.6637076,0.77527237,-0.85642415,0.7988925,0.9016983,0.7194023,-0.57740134,-0.8594171,0.060442865,0.8441894,0.5655705,-0.48184186,0.97267807,-0.0034542084,0.26679605,0.95290154,0.850673,0.7279086,0.32183564,0.9643708,0.96563125,-0.4683205,-0.47591025,0.85103375,0.22617435,-0.49340868,-0.7442463,-0.80971164,0.49820942,0.5542913,0.18450409,-0.73644435,-0.66192,-0.7001095,0.7091956,-0.4261573,-0.14492083,0.08407277,-0.9962735,0.9104786,-0.8721442,-0.008581877,0.99831814,0.018963218,-0.63647544,-0.1374923,0.14023751,0.27209592,-0.12910527,-0.60420024,-0.19298297,0.90737826,-0.8328062,0.062616944,-0.87050116,0.97018605,-0.6915035,0.75230813,-0.022474527,-0.568987,0.978216,-0.8371682,-0.64269274,0.9948615,-0.097065926,-0.4056685,0.2569118,0.8531618,-0.429191,0.7659323,0.1264903,-0.28168094,-0.23540032,0.4171837,0.8381529,0.93010795,0.8519289,0.94049615,0.34832448,0.9809617,-0.8306934,0.13476497,0.7351035,-0.4222901,-0.9695115,-0.52205384,0.17444205,-0.9326548,0.9328214,0.35107726,-0.90313464,-0.5120796,-0.7681321,0.7650299,-0.8309043,-0.41717684,-0.5633987,0.9926045,-0.2035985,-0.8018237,-0.5571686,0.80306566,0.7222599,0.8201566,-0.23658323,-0.8803988,-0.30664307,0.8875331,-0.5045499,0.82044584,0.96209013,-0.8 ...
